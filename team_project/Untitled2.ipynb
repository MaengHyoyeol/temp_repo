# %%
import csv
import pickle
import datetime
from sklearn.model_selection import train_test_split

# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png','retina'}

# %%
def import_data():
    df = pd.read_csv('data/data.csv')
    df = df.iloc[:,1:]
    
    return df

# %%
full_frame = import_data()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2850: DtypeWarning: Columns (6,7,8,10,12,13,14,15,18,20,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
full_frame
# Out:
#               date  store_nbr  item_nbr  units  station_nbr tmax tmin tavg  \
# 0       2012-01-01          1         9   29.0            1   52   31   42
# 1       2012-01-01          1        28    2.0            1   52   31   42
# 2       2012-01-01          1        40    0.0            1   52   31   42
# 3       2012-01-01          1        47    0.0            1   52   31   42
# 4       2012-01-01          1        51    1.0            1   52   31   42
# 5       2012-01-01          1        89    0.0            1   52   31   42
# 6       2012-01-01          1        93    0.0            1   52   31   42
# 7       2012-01-01          1        99    0.0            1   52   31   42
# 8       2012-01-02          1         9   60.0            1   50   31   41
# 9       2012-01-02          1        28    5.0            1   50   31   41
# 10      2012-01-02          1        40    0.0            1   50   31   41
# 11      2012-01-02          1        47    0.0            1   50   31   41
# 12      2012-01-02          1        51    1.0            1   50   31   41
# 13      2012-01-02          1        89    0.0            1   50   31   41
# 14      2012-01-02          1        93    0.0            1   50   31   41
# 15      2012-01-02          1        99    0.0            1   50   31   41
# 16      2012-01-03          1         9   15.0            1   32   11   22
# 17      2012-01-03          1        28    9.0            1   32   11   22
# 18      2012-01-03          1        40    0.0            1   32   11   22
# 19      2012-01-03          1        47    0.0            1   32   11   22
# 20      2012-01-03          1        51    0.0            1   32   11   22
# 21      2012-01-03          1        89    0.0            1   32   11   22
# 22      2012-01-03          1        93    0.0            1   32   11   22
# 23      2012-01-03          1        99    0.0            1   32   11   22
# 24      2012-01-04          1         9   20.0            1   28    9   19
# 25      2012-01-04          1        28    3.0            1   28    9   19
# 26      2012-01-04          1        40    0.0            1   28    9   19
# 27      2012-01-04          1        47    0.0            1   28    9   19
# 28      2012-01-04          1        51    0.0            1   28    9   19
# 29      2012-01-04          1        89    0.0            1   28    9   19
# ...            ...        ...       ...    ...          ...  ...  ...  ...
# 262176  2014-10-24         39       103    0.0            8   84   56   70
# 262177  2014-10-24         39       111    5.0            8   84   56   70
# 262178  2014-10-25         39         9    8.0            8   87   58   73
# 262179  2014-10-25         39        36    1.0            8   87   58   73
# 262180  2014-10-25         39       103    2.0            8   87   58   73
# 262181  2014-10-25         39       111    1.0            8   87   58   73
# 262182  2014-10-26         39         9    3.0            8   86   57   72
# 262183  2014-10-26         39        36    3.0            8   86   57   72
# 262184  2014-10-26         39       103    1.0            8   86   57   72
# 262185  2014-10-26         39       111    5.0            8   86   57   72
# 262186  2014-10-27         39         9   13.0            8   86   61   74
# 262187  2014-10-27         39        36    3.0            8   86   61   74
# 262188  2014-10-27         39       103    0.0            8   86   61   74
# 262189  2014-10-27         39       111    9.0            8   86   61   74
# 262190  2014-10-28         39         9    6.0            8   85   62   74
# 262191  2014-10-28         39        36    4.0            8   85   62   74
# 262192  2014-10-28         39       103    0.0            8   85   62   74
# 262193  2014-10-28         39       111    5.0            8   85   62   74
# 262194  2014-10-29         39         9   11.0            8   77   64   71
# 262195  2014-10-29         39        36    7.0            8   77   64   71
# 262196  2014-10-29         39       103    0.0            8   77   64   71
# 262197  2014-10-29         39       111    6.0            8   77   64   71
# 262198  2014-10-30         39         9    6.0            8   82   59   71
# 262199  2014-10-30         39        36    2.0            8   82   59   71
# 262200  2014-10-30         39       103    0.0            8   82   59   71
# 262201  2014-10-30         39       111    3.0            8   82   59   71
# 262202  2014-10-31         39         9   12.0            8   78   55   67
# 262203  2014-10-31         39        36    3.0            8   78   55   67
# 262204  2014-10-31         39       103    4.0            8   78   55   67
# 262205  2014-10-31         39       111    2.0            8   78   55   67
#
#        depart dewpoint  ...       HZ     FU     DU     SQ     FZ     MI  \
# 0           M       36  ...    False  False  False  False   True  False
# 1           M       36  ...    False  False  False  False   True  False
# 2           M       36  ...    False  False  False  False   True  False
# 3           M       36  ...    False  False  False  False   True  False
# 4           M       36  ...    False  False  False  False   True  False
# 5           M       36  ...    False  False  False  False   True  False
# 6           M       36  ...    False  False  False  False   True  False
# 7           M       36  ...    False  False  False  False   True  False
# 8           M       26  ...    False  False  False  False  False  False
# 9           M       26  ...    False  False  False  False  False  False
# 10          M       26  ...    False  False  False  False  False  False
# 11          M       26  ...    False  False  False  False  False  False
# 12          M       26  ...    False  False  False  False  False  False
# 13          M       26  ...    False  False  False  False  False  False
# 14          M       26  ...    False  False  False  False  False  False
# 15          M       26  ...    False  False  False  False  False  False
# 16          M        4  ...    False  False  False  False  False  False
# 17          M        4  ...    False  False  False  False  False  False
# 18          M        4  ...    False  False  False  False  False  False
# 19          M        4  ...    False  False  False  False  False  False
# 20          M        4  ...    False  False  False  False  False  False
# 21          M        4  ...    False  False  False  False  False  False
# 22          M        4  ...    False  False  False  False  False  False
# 23          M        4  ...    False  False  False  False  False  False
# 24          M       -1  ...    False  False  False  False  False  False
# 25          M       -1  ...    False  False  False  False  False  False
# 26          M       -1  ...    False  False  False  False  False  False
# 27          M       -1  ...    False  False  False  False  False  False
# 28          M       -1  ...    False  False  False  False  False  False
# 29          M       -1  ...    False  False  False  False  False  False
# ...       ...      ...  ...      ...    ...    ...    ...    ...    ...
# 262176      M       59  ...     True  False  False  False  False  False
# 262177      M       59  ...     True  False  False  False  False  False
# 262178      M       61  ...    False  False  False  False  False  False
# 262179      M       61  ...    False  False  False  False  False  False
# 262180      M       61  ...    False  False  False  False  False  False
# 262181      M       61  ...    False  False  False  False  False  False
# 262182      M       60  ...    False  False  False  False  False  False
# 262183      M       60  ...    False  False  False  False  False  False
# 262184      M       60  ...    False  False  False  False  False  False
# 262185      M       60  ...    False  False  False  False  False  False
# 262186      M       64  ...     True  False  False  False  False  False
# 262187      M       64  ...     True  False  False  False  False  False
# 262188      M       64  ...     True  False  False  False  False  False
# 262189      M       64  ...     True  False  False  False  False  False
# 262190      M       66  ...    False  False  False  False  False  False
# 262191      M       66  ...    False  False  False  False  False  False
# 262192      M       66  ...    False  False  False  False  False  False
# 262193      M       66  ...    False  False  False  False  False  False
# 262194      M       66  ...    False  False  False  False  False  False
# 262195      M       66  ...    False  False  False  False  False  False
# 262196      M       66  ...    False  False  False  False  False  False
# 262197      M       66  ...    False  False  False  False  False  False
# 262198      M       60  ...     True  False  False  False  False  False
# 262199      M       60  ...     True  False  False  False  False  False
# 262200      M       60  ...     True  False  False  False  False  False
# 262201      M       60  ...     True  False  False  False  False  False
# 262202      M        M  ...    False  False  False  False  False  False
# 262203      M        M  ...    False  False  False  False  False  False
# 262204      M        M  ...    False  False  False  False  False  False
# 262205      M        M  ...    False  False  False  False  False  False
#
#            PR     BC     BL     VC
# 0       False  False  False  False
# 1       False  False  False  False
# 2       False  False  False  False
# 3       False  False  False  False
# 4       False  False  False  False
# 5       False  False  False  False
# 6       False  False  False  False
# 7       False  False  False  False
# 8       False  False  False  False
# 9       False  False  False  False
# 10      False  False  False  False
# 11      False  False  False  False
# 12      False  False  False  False
# 13      False  False  False  False
# 14      False  False  False  False
# 15      False  False  False  False
# 16      False  False  False  False
# 17      False  False  False  False
# 18      False  False  False  False
# 19      False  False  False  False
# 20      False  False  False  False
# 21      False  False  False  False
# 22      False  False  False  False
# 23      False  False  False  False
# 24      False  False  False  False
# 25      False  False  False  False
# 26      False  False  False  False
# 27      False  False  False  False
# 28      False  False  False  False
# 29      False  False  False  False
# ...       ...    ...    ...    ...
# 262176  False  False  False  False
# 262177  False  False  False  False
# 262178  False  False  False  False
# 262179  False  False  False  False
# 262180  False  False  False  False
# 262181  False  False  False  False
# 262182  False  False  False  False
# 262183  False  False  False  False
# 262184  False  False  False  False
# 262185  False  False  False  False
# 262186  False  False  False  False
# 262187  False  False  False  False
# 262188  False  False  False  False
# 262189  False  False  False  False
# 262190  False  False  False  False
# 262191  False  False  False  False
# 262192  False  False  False  False
# 262193  False  False  False  False
# 262194  False  False  False  False
# 262195  False  False  False  False
# 262196  False  False  False  False
# 262197  False  False  False  False
# 262198  False  False  False  False
# 262199  False  False  False  False
# 262200  False  False  False  False
# 262201  False  False  False  False
# 262202  False  False  False  False
# 262203  False  False  False  False
# 262204  False  False  False  False
# 262205  False  False  False  False
#
# [262206 rows x 44 columns]

# %%
full_frame.snowfall = full_frame.snowfall.replace(["T","  T"],0.05)
full_frame.preciptotal = full_frame.preciptotal.replace(["T","  T"],0.005)

# %%
full_frame.snowfall = full_frame.snowfall.replace(["M","  M"], 0)
full_frame.preciptotal = full_frame.preciptotal.replace(["M","  M"], 0)

# %%
full_frame.isnull().any()
# Out:
# date           False
# store_nbr      False
# item_nbr       False
# units          False
# station_nbr    False
# tmax           False
# tmin           False
# tavg           False
# depart         False
# dewpoint       False
# wetbulb        False
# heat           False
# cool           False
# sunrise         True
# sunset          True
# snowfall       False
# preciptotal    False
# stnpressure    False
# sealevel       False
# avgspeed       False
# resultspeed    False
# resultdir      False
# TS             False
# GR             False
# RA             False
# DZ             False
# SN             False
# SG             False
# GS             False
# PL             False
# FG+            False
# FG             False
# BR             False
# UP             False
# HZ             False
# FU             False
# DU             False
# SQ             False
# FZ             False
# MI             False
# PR             False
# BC             False
# BL             False
# VC             False
# dtype: bool

# %%
full_frame.dtypes
# Out:
# date            object
# store_nbr        int64
# item_nbr         int64
# units          float64
# station_nbr      int64
# tmax            object
# tmin            object
# tavg            object
# depart          object
# dewpoint        object
# wetbulb         object
# heat            object
# cool            object
# sunrise         object
# sunset          object
# snowfall        object
# preciptotal     object
# stnpressure     object
# sealevel        object
# avgspeed        object
# resultspeed     object
# resultdir       object
# TS                bool
# GR                bool
# RA                bool
# DZ                bool
# SN                bool
# SG                bool
# GS                bool
# PL                bool
# FG+               bool
# FG                bool
# BR                bool
# UP                bool
# HZ                bool
# FU                bool
# DU                bool
# SQ                bool
# FZ                bool
# MI                bool
# PR                bool
# BC                bool
# BL                bool
# VC                bool
# dtype: object

# %%
full_frame.columns
# Out:
# Index(['date', 'store_nbr', 'item_nbr', 'units', 'station_nbr', 'tmax', 'tmin',
#        'tavg', 'depart', 'dewpoint', 'wetbulb', 'heat', 'cool', 'sunrise',
#        'sunset', 'snowfall', 'preciptotal', 'stnpressure', 'sealevel',
#        'avgspeed', 'resultspeed', 'resultdir', 'TS', 'GR', 'RA', 'DZ', 'SN',
#        'SG', 'GS', 'PL', 'FG+', 'FG', 'BR', 'UP', 'HZ', 'FU', 'DU', 'SQ', 'FZ',
#        'MI', 'PR', 'BC', 'BL', 'VC'],
#       dtype='object')

# %%
ls = ['store_nbr', 'item_nbr', 'station_nbr', 'tmax', 'tmin',  \
           'tavg', 'depart', 'dewpoint', 'wetbulb', 'heat', 'cool', 'preciptotal', \
           'stnpressure', 'sealevel', 'avgspeed', 'resultspeed', 'units' ]

# %%
cols = full_frame.columns
for i in cols:
    if i in ls:
        #df = df.replace(["M",None], '')
#         full_frame.snowfall = full_frame.snowfall.replace(["T","  T"],0.05)
#         full_frame.preciptotal = full_frame.preciptotal.replace(["T","  T"],0.005)
        full_frame[i] = pd.to_numeric(full_frame[i], errors='coerce')

# %%
full_frame['snowfall'] = pd.to_numeric(full_frame['snowfall'], errors='coerce')

# %%
full_frame.dtypes
# Out:
# date            object
# store_nbr        int64
# item_nbr         int64
# units          float64
# station_nbr      int64
# tmax           float64
# tmin           float64
# tavg           float64
# depart         float64
# dewpoint       float64
# wetbulb        float64
# heat           float64
# cool           float64
# sunrise         object
# sunset          object
# snowfall       float64
# preciptotal    float64
# stnpressure    float64
# sealevel       float64
# avgspeed       float64
# resultspeed    float64
# resultdir       object
# TS                bool
# GR                bool
# RA                bool
# DZ                bool
# SN                bool
# SG                bool
# GS                bool
# PL                bool
# FG+               bool
# FG                bool
# BR                bool
# UP                bool
# HZ                bool
# FU                bool
# DU                bool
# SQ                bool
# FZ                bool
# MI                bool
# PR                bool
# BC                bool
# BL                bool
# VC                bool
# dtype: object
